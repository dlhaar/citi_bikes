# %% [markdown]
# # Gathering and cleaning data
#
# The goal of this project is to predict the number of Citibikes rides in NYC starting at a given station during a given hour depending on the weather.
#
# The Citibikes datasets used in this project (July 2021 - June 2023) contain the following columns:
#
# - `ride_id`
# - `rideable_type`: electric_bike, classic_bike
# - `started_at`
# - `ended at`
# - `start_station_name`
# - `start_station_id`
# - `end_station_name`
# - `end_station_id`
# - `start_lat`
# - `start_lng`
# - `end_lat`
# - `end_long`
# - `rider_type`: member/casual
#
# We will focus on the following columns: `started_at`, `start_station_id`, `start_station_name`, `start_lat`, `start_lng`.
#
# From `started_at`, we will create the following new column:
# - `weekday`
#
# Each row in the dataset is a ride, so we will group by these features and count the number of rows to get the number of rides per station, per hour.
# - `count`

# %%
import pandas as pd
import polars as pl
import glob
import yaml
from functions import yearly_clean_data, concat_dfs, get_station_data
from datetime import datetime

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pl.Config(fmt_str_lengths=50)

# %%
try:
    with open("../config.yaml", 'r') as file:
        config = yaml.safe_load(file)
except Exception as e:
    print('Error reading config file')

# %% [markdown]
# ## Getting Data
#
# ### Bike trip data

# %%
data_2021 = yearly_clean_data('../data/raw/2021*.csv')
# Out:
# The total rows in the entire df is 521918
# Total rows: 76235, total count 521918
# total rows: 76235, total count in the concated df is 521918

# %%
data_2021.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬─────────┬──────────────────┬───────┐
# │ started_at_rounded  ┆ weekday ┆ start_station_id ┆ count │
# │ ---                 ┆ ---     ┆ ---              ┆ ---   │
# │ datetime[μs]        ┆ u32     ┆ str              ┆ u32   │
# ╞═════════════════════╪═════════╪══════════════════╪═══════╡
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 4993.13          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5065.12          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5114.06          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5137.11          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5137.13          ┆ 1     │
# └─────────────────────┴─────────┴──────────────────┴───────┘

# %%
data_2022 = yearly_clean_data('../data/raw/2022*.csv')
# Out:
# The total rows in the entire df is 949054
# Total rows: 158916, total count 949054
# total rows: 158916, total count in the concated df is 949054

# %%
data_2022.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬─────────┬──────────────────┬───────┐
# │ started_at_rounded  ┆ weekday ┆ start_station_id ┆ count │
# │ ---                 ┆ ---     ┆ ---              ┆ ---   │
# │ datetime[μs]        ┆ u32     ┆ str              ┆ u32   │
# ╞═════════════════════╪═════════╪══════════════════╪═══════╡
# │ 2022-01-01 00:00:00 ┆ 6       ┆ 4889.06          ┆ 1     │
# │ 2022-01-01 00:00:00 ┆ 6       ┆ 4953.04          ┆ 1     │
# │ 2022-01-01 00:00:00 ┆ 6       ┆ 4993.13          ┆ 1     │
# │ 2022-01-01 00:00:00 ┆ 6       ┆ 5001.08          ┆ 4     │
# │ 2022-01-01 00:00:00 ┆ 6       ┆ 5065.04          ┆ 3     │
# └─────────────────────┴─────────┴──────────────────┴───────┘

# %%
data_2023 = yearly_clean_data('../data/raw/2023*.csv')
# Out:
# The total rows in the entire df is 450987
# Total rows: 85992, total count 450987
# total rows: 85992, total count in the concated df is 450987

# %%
data_2023.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬─────────┬──────────────────┬───────┐
# │ started_at_rounded  ┆ weekday ┆ start_station_id ┆ count │
# │ ---                 ┆ ---     ┆ ---              ┆ ---   │
# │ datetime[μs]        ┆ u32     ┆ str              ┆ u32   │
# ╞═════════════════════╪═════════╪══════════════════╪═══════╡
# │ 2023-01-01 00:00:00 ┆ 7       ┆ 4889.06          ┆ 1     │
# │ 2023-01-01 00:00:00 ┆ 7       ┆ 4953.04          ┆ 3     │
# │ 2023-01-01 00:00:00 ┆ 7       ┆ 4962.08          ┆ 1     │
# │ 2023-01-01 00:00:00 ┆ 7       ┆ 5001.08          ┆ 3     │
# │ 2023-01-01 00:00:00 ┆ 7       ┆ 5033.01          ┆ 1     │
# └─────────────────────┴─────────┴──────────────────┴───────┘

# %%
all_data_lst = [data_2021, data_2022, data_2023]

# %%
data = concat_dfs(all_data_lst)
# Out:
# total rows: 321143, total count in the concated df is 1921959

# %%
data.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬─────────┬──────────────────┬───────┐
# │ started_at_rounded  ┆ weekday ┆ start_station_id ┆ count │
# │ ---                 ┆ ---     ┆ ---              ┆ ---   │
# │ datetime[μs]        ┆ u32     ┆ str              ┆ u32   │
# ╞═════════════════════╪═════════╪══════════════════╪═══════╡
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 4993.13          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5065.12          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5114.06          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5137.11          ┆ 1     │
# │ 2021-07-01 00:00:00 ┆ 4       ┆ 5137.13          ┆ 1     │
# └─────────────────────┴─────────┴──────────────────┴───────┘

# %%
data.write_csv('../data/cleaned/all_data.csv')

# %% [markdown]
# ### Getting unique station id information
# There are station ids that have different lat and long values for them. We will get station names and one set of lat and long for each station id.

# %%
station_info = get_station_data('../data/raw/2023*.csv')

# %%
station_info.head()
# Out:
# shape: (5, 4)
# ┌──────────────────┬──────────────────────────┬───────────┬────────────┐
# │ start_station_id ┆ start_station_name       ┆ start_lat ┆ start_lng  │
# │ ---              ┆ ---                      ┆ ---       ┆ ---        │
# │ str              ┆ str                      ┆ f64       ┆ f64        │
# ╞══════════════════╪══════════════════════════╪═══════════╪════════════╡
# │ 4846.01          ┆ South St & Whitehall St  ┆ 40.701221 ┆ -74.012342 │
# │ 4889.06          ┆ Bus Slip & State St      ┆ 40.701907 ┆ -74.013942 │
# │ 4953.04          ┆ South St & Gouverneur Ln ┆ 40.703554 ┆ -74.006702 │
# │ 4962.01          ┆ Broadway & Battery Pl    ┆ 40.704633 ┆ -74.013617 │
# │ 4962.02          ┆ Whitehall St & Bridge St ┆ 40.703748 ┆ -74.013133 │
# └──────────────────┴──────────────────────────┴───────────┴────────────┘

# %%
station_info.write_csv('../data/cleaned/station_info.csv')

# %% [markdown]
# ### Weather data
#
# The historical weather data was obtained from [Open-Meteo](https://open-meteo.com).
#
# Historical weather data was downloaded for the date range of the Citibike data, July 1, 2021 through June 30, 2023.

# %%
weather = pl.read_csv(config["data"]["weather"],
                      has_header=False,
                      skip_rows = 4,
                      new_columns=['time', 'temperature_f', 'precipitation_in', 'windspeed_mph'],
                     dtypes={'time':pl.Datetime, 'temperature_F':pl.Float64, 'precipitation_in':pl.Float64, 'windspeed_mph':pl.Float64})

# %%
weather.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬───────────────┬──────────────────┬───────────────┐
# │ time                ┆ temperature_f ┆ precipitation_in ┆ windspeed_mph │
# │ ---                 ┆ ---           ┆ ---              ┆ ---           │
# │ datetime[μs]        ┆ f64           ┆ f64              ┆ f64           │
# ╞═════════════════════╪═══════════════╪══════════════════╪═══════════════╡
# │ 2021-07-01 00:00:00 ┆ 78.6          ┆ 0.0              ┆ 3.2           │
# │ 2021-07-01 01:00:00 ┆ 77.5          ┆ 0.0              ┆ 2.5           │
# │ 2021-07-01 02:00:00 ┆ 76.4          ┆ 0.0              ┆ 2.0           │
# │ 2021-07-01 03:00:00 ┆ 74.9          ┆ 0.0              ┆ 3.2           │
# │ 2021-07-01 04:00:00 ┆ 73.9          ┆ 0.0              ┆ 3.5           │
# └─────────────────────┴───────────────┴──────────────────┴───────────────┘

# %% [markdown]
# Dataset was checked for missing rows, and there are none.

# %%
weather.write_csv('../data/cleaned/weather_clean.csv')

# %% [markdown]
# ## Concating rides, station info, weather data

# %%
data_station = data.join(station_info, how = 'left', on='start_station_id')

# %%
data_station.head()
# Out:
# shape: (5, 7)
# ┌──────────────────┬─────────┬──────────────────┬───────┬─────────────────┬───────────┬────────────┐
# │ started_at_round ┆ weekday ┆ start_station_id ┆ count ┆ start_station_n ┆ start_lat ┆ start_lng  │
# │ ed               ┆ ---     ┆ ---              ┆ ---   ┆ ame             ┆ ---       ┆ ---        │
# │ ---              ┆ u32     ┆ str              ┆ u32   ┆ ---             ┆ f64       ┆ f64        │
# │ datetime[μs]     ┆         ┆                  ┆       ┆ str             ┆           ┆            │
# ╞══════════════════╪═════════╪══════════════════╪═══════╪═════════════════╪═══════════╪════════════╡
# │ 2021-07-01       ┆ 4       ┆ 4993.13          ┆ 1     ┆ Old Slip &      ┆ 40.703367 ┆ -74.007868 │
# │ 00:00:00         ┆         ┆                  ┆       ┆ South St        ┆           ┆            │
# │ 2021-07-01       ┆ 4       ┆ 5065.12          ┆ 1     ┆ William St &    ┆ 40.707179 ┆ -74.008873 │
# │ 00:00:00         ┆         ┆                  ┆       ┆ Pine St         ┆           ┆            │
# │ 2021-07-01       ┆ 4       ┆ 5114.06          ┆ 1     ┆ West Thames St  ┆ 40.708347 ┆ -74.017134 │
# │ 00:00:00         ┆         ┆                  ┆       ┆                 ┆           ┆            │
# │ 2021-07-01       ┆ 4       ┆ 5137.11          ┆ 1     ┆ Fulton St &     ┆ 40.709601 ┆ -74.006551 │
# │ 00:00:00         ┆         ┆                  ┆       ┆ William St      ┆           ┆            │
# │ 2021-07-01       ┆ 4       ┆ 5137.13          ┆ 1     ┆ Spruce St &     ┆ 40.710323 ┆ -74.004323 │
# │ 00:00:00         ┆         ┆                  ┆       ┆ Gold St         ┆           ┆            │
# └──────────────────┴─────────┴──────────────────┴───────┴─────────────────┴───────────┴────────────┘

# %%
data_station_weather = data_station.join(weather, how='left', left_on='started_at_rounded', right_on='time')

# %%
data_station_weather.tail(25)
# Out:
# shape: (25, 10)
# ┌────────────┬─────────┬────────────┬───────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ started_at ┆ weekday ┆ start_stat ┆ count ┆ … ┆ start_lng  ┆ temperatur ┆ precipitat ┆ windspeed │
# │ _rounded   ┆ ---     ┆ ion_id     ┆ ---   ┆   ┆ ---        ┆ e_f        ┆ ion_in     ┆ _mph      │
# │ ---        ┆ u32     ┆ ---        ┆ u32   ┆   ┆ f64        ┆ ---        ┆ ---        ┆ ---       │
# │ datetime[μ ┆         ┆ str        ┆       ┆   ┆            ┆ f64        ┆ f64        ┆ f64       │
# │ s]         ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# ╞════════════╪═════════╪════════════╪═══════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 2023-06-30 ┆ 5       ┆ 5137.11    ┆ 7     ┆ … ┆ -74.006551 ┆ 68.8       ┆ 0.0        ┆ 4.7       │
# │ 23:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-06-30 ┆ 5       ┆ 5145.02    ┆ 2     ┆ … ┆ -74.013093 ┆ 68.8       ┆ 0.0        ┆ 4.7       │
# │ 23:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-06-30 ┆ 5       ┆ 5175.08    ┆ 4     ┆ … ┆ -74.009484 ┆ 68.8       ┆ 0.0        ┆ 4.7       │
# │ 23:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-06-30 ┆ 5       ┆ 5184.08    ┆ 7     ┆ … ┆ -74.014847 ┆ 68.8       ┆ 0.0        ┆ 4.7       │
# │ 23:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ …          ┆ …       ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …          ┆ …         │
# │ 2023-07-01 ┆ 5       ┆ 5184.08    ┆ 6     ┆ … ┆ -74.014847 ┆ null       ┆ null       ┆ null      │
# │ 00:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-07-01 ┆ 5       ┆ 5207.01    ┆ 7     ┆ … ┆ -74.004562 ┆ null       ┆ null       ┆ null      │
# │ 00:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-07-01 ┆ 5       ┆ 5216.06    ┆ 1     ┆ … ┆ -74.010822 ┆ null       ┆ null       ┆ null      │
# │ 00:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# │ 2023-07-01 ┆ 5       ┆ 5329.08    ┆ 1     ┆ … ┆ -74.01246  ┆ null       ┆ null       ┆ null      │
# │ 00:00:00   ┆         ┆            ┆       ┆   ┆            ┆            ┆            ┆           │
# └────────────┴─────────┴────────────┴───────┴───┴────────────┴────────────┴────────────┴───────────┘

# %% [markdown]
# Due to the rounding function, several dates were cast to July 1, 2023. We will drop these values to be consistent with the rounding.

# %%
data_station_weather_clean = data_station_weather.filter(pl.col('started_at_rounded') < datetime(2023, 7, 1))

# %%
data_station_weather_clean.null_count()
# Out:
# shape: (1, 10)
# ┌────────────┬─────────┬────────────┬───────┬───┬───────────┬────────────┬────────────┬────────────┐
# │ started_at ┆ weekday ┆ start_stat ┆ count ┆ … ┆ start_lng ┆ temperatur ┆ precipitat ┆ windspeed_ │
# │ _rounded   ┆ ---     ┆ ion_id     ┆ ---   ┆   ┆ ---       ┆ e_f        ┆ ion_in     ┆ mph        │
# │ ---        ┆ u32     ┆ ---        ┆ u32   ┆   ┆ u32       ┆ ---        ┆ ---        ┆ ---        │
# │ u32        ┆         ┆ u32        ┆       ┆   ┆           ┆ u32        ┆ u32        ┆ u32        │
# ╞════════════╪═════════╪════════════╪═══════╪═══╪═══════════╪════════════╪════════════╪════════════╡
# │ 0          ┆ 0       ┆ 0          ┆ 0     ┆ … ┆ 0         ┆ 0          ┆ 0          ┆ 0          │
# └────────────┴─────────┴────────────┴───────┴───┴───────────┴────────────┴────────────┴────────────┘

# %%
data_station_weather_clean.write_csv('../data/cleaned/data_station_weather_clean.csv')

# %% [markdown]
# ## Getting forecast data
#
# The forecasted weather data was obtained from [Open-Meteo](https://open-meteo.com) through their open API.
#
# The forecast is the 3-day forecast for NYC.

# %%
import json
import requests

# %%
api_call = "https://api.open-meteo.com/v1/forecast?latitude=40.7143&longitude=-74.006&hourly=temperature_2m,precipitation,windspeed_10m&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FNew_York&forecast_days=3"

response = requests.get(api_call)
print(response.status_code)
results = response.json()
results
# Out:
# 200
# {'latitude': 40.710335,
#  'longitude': -73.99307,
#  'generationtime_ms': 0.45096874237060547,
#  'utc_offset_seconds': -14400,
#  'timezone': 'America/New_York',
#  'timezone_abbreviation': 'EDT',
#  'elevation': 51.0,
#  'hourly_units': {'time': 'iso8601',
#   'temperature_2m': '°F',
#   'precipitation': 'inch',
#   'windspeed_10m': 'mp/h'},
#  'hourly': {'time': ['2023-08-04T00:00',
#    '2023-08-04T01:00',
#    '2023-08-04T02:00',
#    '2023-08-04T03:00',
#    '2023-08-04T04:00',
#    '2023-08-04T05:00',
#    '2023-08-04T06:00',
#    '2023-08-04T07:00',
#    '2023-08-04T08:00',
#    '2023-08-04T09:00',
#    '2023-08-04T10:00',
#    '2023-08-04T11:00',
#    '2023-08-04T12:00',
#    '2023-08-04T13:00',
#    '2023-08-04T14:00',
#    '2023-08-04T15:00',
#    '2023-08-04T16:00',
#    '2023-08-04T17:00',
#    '2023-08-04T18:00',
#    '2023-08-04T19:00',
#    '2023-08-04T20:00',
#    '2023-08-04T21:00',
#    '2023-08-04T22:00',
#    '2023-08-04T23:00',
#    '2023-08-05T00:00',
#    '2023-08-05T01:00',
#    '2023-08-05T02:00',
#    '2023-08-05T03:00',
#    '2023-08-05T04:00',
#    '2023-08-05T05:00',
#    '2023-08-05T06:00',
#    '2023-08-05T07:00',
#    '2023-08-05T08:00',
# 56  2023-08-06T08:00            73.0            0.0            8.3
# 57  2023-08-06T09:00            75.2            0.0            7.2
# 58  2023-08-06T10:00            77.5            0.0            6.8
# 59  2023-08-06T11:00            80.4            0.0            5.0
# 60  2023-08-06T12:00            83.1            0.0            3.2
# 61  2023-08-06T13:00            85.3            0.0            1.7
# 62  2023-08-06T14:00            84.9            0.0            6.0
# 63  2023-08-06T15:00            82.4            0.0           10.7
# 64  2023-08-06T16:00            81.9            0.0           12.7
# 65  2023-08-06T17:00            80.8            0.0           13.1
# 66  2023-08-06T18:00            79.5            0.0           11.7
# 67  2023-08-06T19:00            77.7            0.0           11.3
# 68  2023-08-06T20:00            76.6            0.0           10.6
# 69  2023-08-06T21:00            76.8            0.0            9.3
# 70  2023-08-06T22:00            77.0            0.0            8.7
# 71  2023-08-06T23:00            76.3            0.0            9.3

# %%
forecast_3day.to_csv("../data/raw/forecast_3day.csv", index=False)

# %%
forecast_3day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            72 non-null     object
#  1   temperature_2m  72 non-null     float64
#  2   precipitation   72 non-null     float64
#  3   windspeed_10m   72 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.4+ KB

# %%
forecast_3day_clean = forecast_3day.copy()
forecast_3day_clean['time']=pd.to_datetime(forecast_3day_clean['time'], format="%Y-%m-%dT%H:%M").dt.strftime('%Y-%m-%d %H:%M:%S')

forecast_3day_clean.columns = ['started_at_rounded', 'temperature_f', 'precipitation_in', 'windspeed_mph']

# %%
forecast_3day_clean
# Out:
#      started_at_rounded  temperature_f  precipitation_in  windspeed_mph
# 0   2023-08-04 00:00:00           72.0               0.0            9.4
# 1   2023-08-04 01:00:00           71.2               0.0           10.5
# 2   2023-08-04 02:00:00           73.1               0.0            9.5
# 3   2023-08-04 03:00:00           69.8               0.0            9.0
# 4   2023-08-04 04:00:00           70.4               0.0            8.2
# 5   2023-08-04 05:00:00           69.5               0.0            8.7
# 6   2023-08-04 06:00:00           70.3               0.0           10.4
# 7   2023-08-04 07:00:00           70.8               0.0           10.3
# 8   2023-08-04 08:00:00           72.3               0.0           10.7
# 9   2023-08-04 09:00:00           73.3               0.0           10.2
# 10  2023-08-04 10:00:00           75.9               0.0           10.6
# 11  2023-08-04 11:00:00           77.6               0.0           12.3
# 12  2023-08-04 12:00:00           78.7               0.0           12.8
# 13  2023-08-04 13:00:00           77.8               0.0           10.4
# 14  2023-08-04 14:00:00           79.9               0.0           12.3
# 15  2023-08-04 15:00:00           81.0               0.0           13.4
# 16  2023-08-04 16:00:00           81.7               0.0           12.9
# 17  2023-08-04 17:00:00           80.3               0.0           14.7
# 18  2023-08-04 18:00:00           78.5               0.0           14.8
# 19  2023-08-04 19:00:00           76.3               0.0           12.2
# 20  2023-08-04 20:00:00           74.7               0.0            8.4
# 21  2023-08-04 21:00:00           74.0               0.0            5.9
# 22  2023-08-04 22:00:00           72.8               0.0            4.3
# 23  2023-08-04 23:00:00           72.3               0.0            8.7
# 24  2023-08-05 00:00:00           71.7               0.0            8.1
# 25  2023-08-05 01:00:00           71.3               0.0            3.3
# 26  2023-08-05 02:00:00           70.8               0.0            7.6
# 27  2023-08-05 03:00:00           70.2               0.0            6.4
# 28  2023-08-05 04:00:00           69.1               0.0            3.3
# 29  2023-08-05 05:00:00           67.3               0.0            5.3
# 30  2023-08-05 06:00:00           65.9               0.0            2.3
# 31  2023-08-05 07:00:00           67.6               0.0            2.0
# 32  2023-08-05 08:00:00           71.3               0.0            7.1
# 33  2023-08-05 09:00:00           75.0               0.0            5.4
# 34  2023-08-05 10:00:00           78.9               0.0            6.8
# 35  2023-08-05 11:00:00           82.0               0.0            7.2
# 36  2023-08-05 12:00:00           84.1               0.0            8.5
# 37  2023-08-05 13:00:00           85.6               0.0            8.5
# 38  2023-08-05 14:00:00           86.6               0.0            8.4
# 39  2023-08-05 15:00:00           87.4               0.0            7.8
# 40  2023-08-05 16:00:00           87.8               0.0            7.6
# 41  2023-08-05 17:00:00           87.5               0.0            7.3
# 42  2023-08-05 18:00:00           85.4               0.0            4.3
# 43  2023-08-05 19:00:00           81.3               0.0            7.6
# 44  2023-08-05 20:00:00           78.0               0.0            5.5
# 45  2023-08-05 21:00:00           75.9               0.0            2.0
# 46  2023-08-05 22:00:00           74.3               0.0            2.2
# 47  2023-08-05 23:00:00           73.1               0.0            2.9
# 48  2023-08-06 00:00:00           73.0               0.0            2.6
# 49  2023-08-06 01:00:00           71.9               0.0            0.7
# 50  2023-08-06 02:00:00           70.3               0.0            0.7
# 51  2023-08-06 03:00:00           75.7               0.0            8.1
# 52  2023-08-06 04:00:00           74.1               0.0            9.0
# 53  2023-08-06 05:00:00           72.3               0.0            8.4
# 54  2023-08-06 06:00:00           71.6               0.0            6.8
# 55  2023-08-06 07:00:00           71.6               0.0            7.3
# 56  2023-08-06 08:00:00           73.0               0.0            8.3
# 57  2023-08-06 09:00:00           75.2               0.0            7.2
# 58  2023-08-06 10:00:00           77.5               0.0            6.8
# 59  2023-08-06 11:00:00           80.4               0.0            5.0
# 60  2023-08-06 12:00:00           83.1               0.0            3.2
# 61  2023-08-06 13:00:00           85.3               0.0            1.7
# 62  2023-08-06 14:00:00           84.9               0.0            6.0
# 63  2023-08-06 15:00:00           82.4               0.0           10.7
# 64  2023-08-06 16:00:00           81.9               0.0           12.7
# 65  2023-08-06 17:00:00           80.8               0.0           13.1
# 66  2023-08-06 18:00:00           79.5               0.0           11.7
# 67  2023-08-06 19:00:00           77.7               0.0           11.3
# 68  2023-08-06 20:00:00           76.6               0.0           10.6
# 69  2023-08-06 21:00:00           76.8               0.0            9.3
# 70  2023-08-06 22:00:00           77.0               0.0            8.7
# 71  2023-08-06 23:00:00           76.3               0.0            9.3

# %%
forecast_3day_clean.shape[0]
# Out:
# 72

# %%
forecast_3day_clean.to_csv('../data/cleaned/forecast_3day_clean.csv', index=False)

# %% [markdown]
# ### Combine station info with forecast data to use in the predictions

# %%
forecast_pl = pl.from_pandas(forecast_3day_clean)
prediction_data = station_info.join(forecast_pl, how="cross")

# %%
prediction_data.shape[0]
# Out:
# 2160

# %%
prediction_data
# Out:
# shape: (2_160, 8)
# ┌────────────┬────────────┬───────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ start_stat ┆ start_stat ┆ start_lat ┆ start_lng  ┆ started_a ┆ temperatu ┆ precipita ┆ windspeed │
# │ ion_id     ┆ ion_name   ┆ ---       ┆ ---        ┆ t_rounded ┆ re_f      ┆ tion_in   ┆ _mph      │
# │ ---        ┆ ---        ┆ f64       ┆ f64        ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ str        ┆           ┆            ┆ str       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 4846.01    ┆ South St & ┆ 40.701221 ┆ -74.012342 ┆ 2023-08-0 ┆ 72.0      ┆ 0.0       ┆ 9.4       │
# │            ┆ Whitehall  ┆           ┆            ┆ 4         ┆           ┆           ┆           │
# │            ┆ St         ┆           ┆            ┆ 00:00:00  ┆           ┆           ┆           │
# │ 4846.01    ┆ South St & ┆ 40.701221 ┆ -74.012342 ┆ 2023-08-0 ┆ 71.2      ┆ 0.0       ┆ 10.5      │
# │            ┆ Whitehall  ┆           ┆            ┆ 4         ┆           ┆           ┆           │
# │            ┆ St         ┆           ┆            ┆ 01:00:00  ┆           ┆           ┆           │
# │ 4846.01    ┆ South St & ┆ 40.701221 ┆ -74.012342 ┆ 2023-08-0 ┆ 73.1      ┆ 0.0       ┆ 9.5       │
# │            ┆ Whitehall  ┆           ┆            ┆ 4         ┆           ┆           ┆           │
# │            ┆ St         ┆           ┆            ┆ 02:00:00  ┆           ┆           ┆           │
# │ 4846.01    ┆ South St & ┆ 40.701221 ┆ -74.012342 ┆ 2023-08-0 ┆ 69.8      ┆ 0.0       ┆ 9.0       │
# │            ┆ Whitehall  ┆           ┆            ┆ 4         ┆           ┆           ┆           │
# │            ┆ St         ┆           ┆            ┆ 03:00:00  ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …         ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 5329.08    ┆ Murray St  ┆ 40.71503  ┆ -74.01246  ┆ 2023-08-0 ┆ 76.6      ┆ 0.0       ┆ 10.6      │
# │            ┆ & West St  ┆           ┆            ┆ 6         ┆           ┆           ┆           │
# │            ┆            ┆           ┆            ┆ 20:00:00  ┆           ┆           ┆           │
# │ 5329.08    ┆ Murray St  ┆ 40.71503  ┆ -74.01246  ┆ 2023-08-0 ┆ 76.8      ┆ 0.0       ┆ 9.3       │
# │            ┆ & West St  ┆           ┆            ┆ 6         ┆           ┆           ┆           │
# │            ┆            ┆           ┆            ┆ 21:00:00  ┆           ┆           ┆           │
# │ 5329.08    ┆ Murray St  ┆ 40.71503  ┆ -74.01246  ┆ 2023-08-0 ┆ 77.0      ┆ 0.0       ┆ 8.7       │
# │            ┆ & West St  ┆           ┆            ┆ 6         ┆           ┆           ┆           │
# │            ┆            ┆           ┆            ┆ 22:00:00  ┆           ┆           ┆           │
# │ 5329.08    ┆ Murray St  ┆ 40.71503  ┆ -74.01246  ┆ 2023-08-0 ┆ 76.3      ┆ 0.0       ┆ 9.3       │
# │            ┆ & West St  ┆           ┆            ┆ 6         ┆           ┆           ┆           │
# │            ┆            ┆           ┆            ┆ 23:00:00  ┆           ┆           ┆           │
# └────────────┴────────────┴───────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %%
prediction_data.write_csv('../data/cleaned/prediction_data.csv')
